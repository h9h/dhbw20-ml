# %%
import numpy as np

n_sample=50

rng = np.random.default_rng(1)
# x = -1 + 4 * rng.random(n_sample)
x = np.linspace(-1,3,n_sample)
y = x - 2 * (x ** 2) + 0.5 * (x ** 3) + 0.2 * rng.standard_normal(n_sample)

# %%
from PolyRegPlot import poly_regr

# %%
poly_regr(x, y, 1);

# %%
poly_regr(x, y, 2);

# %%
poly_regr(x, y, 3);

# %%
poly_regr(x, y, 10);

# %%
poly_regr(x, y, 20);

# %%
poly_regr(x, y, 30);

# %%
poly_regr(x, y, 35);

# %%
poly_regr(x, y, 50);
